# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UHyktOJItLCysW0ino5D")
project = rf.workspace("new-workspace-iuwda").project("plant-village-9vp8g")
dataset = project.version(1).download("yolov8")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.99, to fix: `pip install ultralytics<=8.0.20`
#
# Version export complete for yolov8 format
# ...
# Extracting Dataset Version Zip to plant-village-1 in yolov8:: 100%|██████████████| 1416/1416 [00:00<00:00, 2808.15it/s]

# %%
dataset.location
# Out:
# 'C:\\Users\\rushi\\Untitled Folder\\plant-village-1'

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from YAML

# Train the model
results = model.train(data=dataset.location+"\\data.yaml", epochs=100, imgsz=640)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.0.99  Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 8192MiB)
# YOLOv8n summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Users\rushi\Untitled Folder\plant-village-1\valid\labels.cache... 141 images, 0 backgrounds, 0 corrupt
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 9/9 [00:02<0
#                    all        141        246      0.625       0.46      0.431      0.256
#               bad leaf        141        201        0.6      0.428       0.38      0.221
#              good leaf        141         45      0.649      0.493      0.483      0.292
# Speed: 2.8ms preprocess, 4.4ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs\detect\val
# array([     0.2208,     0.29203])

# %%
# Define path to the image file
source = 'C:/Users/rushi/Untitled Folder/plant-village-1/train/images/2f9e1c60-06fc-41e9-af7d-a91c4a5e9f3d___GH_HL-Leaf-504-1_JPG.rf.25d8a3d5b7012a157e4b4fabca5e15f7.jpg'
# Run inference on the source
results = model(source)
# Out:
# image 1/1 C:\Users\rushi\Untitled Folder\plant-village-1\train\images\2f9e1c60-06fc-41e9-af7d-a91c4a5e9f3d___GH_HL-Leaf-504-1_JPG.rf.25d8a3d5b7012a157e4b4fabca5e15f7.jpg: 640x640 1 good leaf, 55.0ms
# Speed: 5.0ms preprocess, 55.0ms inference, 4.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
model = YOLO('C:/Users/rushi/Untitled Folder/runs/detect/train4/weights/best.pt')

# %%
import cv2

cap = cv2.VideoCapture(0)

# Create a window
cv2.namedWindow("YOLOv8 Inference", cv2.WINDOW_NORMAL)

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot()

        # Display the annotated frame
        cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed or the window is closed
        if cv2.waitKey(1) & 0xFF == ord("q") or cv2.getWindowProperty("YOLOv8 Inference", 0) < 0:
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 bad leaf, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 7.0ms
# Speed: 1.0ms preprocess, 7.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 5.0ms
# Speed: 1.0ms preprocess, 5.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 6.0ms
# Speed: 1.0ms preprocess, 6.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 1 good leaf, 6.0ms
# ...
